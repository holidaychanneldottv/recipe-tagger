# %%
# %pip install sqlalchemy
# %pip install psycopg2-binary
from sqlalchemy import create_engine, text

engine = create_engine("postgresql://postgres@localhost:5432/holiday_channel")
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Tag - tag key words mapping

holiday_keywords = {
    "Thanksgiving": ["turkey", "stuffing", "cranberry sauce", "pumpkin pie", "sweet potatoes", "green bean casserole", "gravy"],
    "Independence Day": ["bbq", "barbecue", "grilled corn", "hot dog", "hamburger", "apple pie", "baked beans", "coleslaw"],
    "Memorial Day": ["bbq", "grilled chicken", "potato salad", "watermelon", "deviled eggs", "lemonade"],
    "Labor Day": ["burgers", "grill", "barbecue", "hot dogs", "pasta salad", "peach cobbler"],
    "Veterans Day": ["comfort food", "mashed potatoes", "fried chicken", "cornbread"],
    "New Year’s Day": ["black-eyed peas", "collard greens", "cornbread", "pork roast", "lucky foods"],
    "Presidents’ Day": ["cherry pie", "apple pie", "colonial dishes"],
    "Martin Luther King Jr. Day": ["soul food", "fried chicken", "mac and cheese", "collard greens", "cornbread"],
    "Juneteenth": ["red velvet cake", "watermelon", "red soda", "bbq", "fried chicken", "black-eyed peas"],
    "Columbus Day": ["Italian dishes", "pasta", "meatballs", "lasagna"],
    "Halloween": ["candy", "pumpkin", "caramel apples", "ghost cookies", "spooky treats"],
    "Earth Day": ["organic", "plant-based", "vegan", "sustainable", "farm-to-table"], 
    "Mother's Day": ["brunch", "quiche", "mimosa", "pancakes", "frittata", "fruit salad"],
    "Father's Day": ["steak", "bbq ribs", "grilled meats", "beer"],
    "Christmas": ["eggnog", "gingerbread", "roast beef", "ham", "plum cake", "sugar cookies", "fruitcake"],
    "Easter": ["hot cross buns", "deviled eggs", "ham", "lamb", "easter bread", "carrot cake"],
    "Hanukkah": ["latkes", "sufganiyot", "brisket", "noodle kugel", "matzo", "applesauce"],
    "Passover": ["matzo", "gefilte fish", "charoset", "brisket", "kugel"],
    "Ramadan": ["dates", "iftar", "harira", "samosas", "lentil soup"],
    "Eid al-Fitr": ["biryani", "sheer khurma", "seviyan", "kebabs", "korma"],
    "Eid al-Adha": ["mutton", "biryani", "kebabs", "korma", "sweet dishes"],
    "Diwali": ["laddu", "burfi", "halwa", "chakli", "peda", "chivda", "sweets"],
    "Holi": ["gujiya", "thandai", "malpua", "dahi bhalla", "saffron milk"],
    "Rosh Hashanah": ["honey cake", "challah", "brisket", "apples and honey", "tzimmes"],
    "Yom Kippur": ["bagels", "lox", "break-fast dishes", "challah", "noodle kugel"],
    "Orthodox Easter": ["kulich", "paska", "roast lamb", "beet salad"],
    "Orthodox Christmas": ["kutya", "borscht", "roast pork", "pierogi"],
    "Kwanzaa": ["jollof rice", "black-eyed peas", "sweet potato pie", "collard greens"],
    "Chinese New Year": ["dumplings", "spring rolls", "longevity noodles", "nian gao", "whole fish"],
    "Navratri": ["sabudana", "kuttu flour", "vrat dishes", "fruit-based", "aloo tikki"],
    "Game Day / Super Bowl": ["buffalo wings", "nachos", "pizza", "sliders", "7-layer dip"],
    "Valentine’s Day": ["chocolate", "strawberries", "fondue", "heart-shaped", "red velvet"],
    "St. Patrick’s Day": ["corned beef", "cabbage", "irish stew", "soda bread", "green beer"],
    "Mardi Gras": ["king cake", "beignets", "gumbo", "jambalaya", "crawfish"],
    "Cinco de Mayo": ["tacos", "margaritas", "guacamole", "enchiladas", "salsa"],
    "Pride Month": ["rainbow cake", "colorful cookies", "festive treats"], 
    "Thanksgiving": ["leftover turkey", "turkey sandwich", "pumpkin pancakes", "stuffing waffles"],
    "Lunar New Year": ["lunar new year", "chinese new year", "spring festival", "reunion dinner"],
    "Nowruz": ["nowruz", "persian new year", "haft-seen", "sabzi polo", "kuku sabzi"],
    "Oktoberfest": ["oktoberfest", "beer", "bratwurst", "sauerkraut", "pretzel", "german fest"],
    "Carnival": ["carnival", "mardi gras", "samba", "king cake", "brazil", "parade food"],
    "Arab American Heritage Month": [
        "hummus", "falafel", "tabbouleh", "shawarma", "baklava", "arabic", "middle eastern"
    ],
    "Jewish American Heritage Month": [
        "matzo", "latkes", "brisket", "kugel", "bagel", "challah", "kosher", "lox", "gefilte"
    ],
    "Native American Heritage Month": [
        "cornbread", "frybread", "succotash", "bison", "venison", "three sisters", "native american", "wild rice"
    ],
    "Ganesh Chaturthi": [
        "modak", "ladoo", "ganesh chaturthi", "indian sweet", "maharashtrian"
    ],
    "Asian American and Pacific Islander Heritage Month": [
        "asian", "dumpling", "noodle", "sushi", "bibimbap", "pho", "ramen", "boba", "spam musubi", "poke", "filipino", "korean", "thai", "vietnamese", "japanese", "pacific islander"
    ],
    "Hispanic Heritage Month": [
        "taco", "empanada", "tamale", "enchilada", "salsa", "plantain", "arepa", "ceviche", "hispanic", "latin", "mexican", "puerto rican", "cuban", "peruvian", "colombian"
    ],
    "Black History Month": [
        "soul food", "collard greens", "fried chicken", "mac and cheese", "gumbo", "jambalaya", "sweet potato pie", "cornbread", "african american"
    ],
    "Women's History Month": [
        "women’s day", "inspired by women", "female chef", "grandma's recipe", "home cooking", "heritage recipe"
    ],
    "Vaisakhi": [
        "langar", "kadha prasad", "punjabi", "wheat roti", "chole", "paneer", "sikh festival", "vaisakhi"
    ],
    "Onam": [
        "onam", "onam sadya", "avial", "parippu", "payasam", "banana chips", "kerala"
    ],
    "Day of the Dead": [
        "dia de los muertos", "pan de muerto", "calaveras", "mexican holiday", "sugar skull"
    ],
    "Tet": [
        "tet", "banh chung", "banh tet", "vietnamese new year", "spring roll", "thit kho", "pickled vegetables"
    ]
}

    # add-on holidays
    # "Election Day": ["pizza", "chili", "easy meals", "casserole"],
    # "Flag Day": ["red white and blue desserts", "flag cake", "patriotic cookies"],
    # "Spring": ["asparagus", "lemon tart", "pea soup", "strawberries", "deviled eggs"],
    # "Summer": ["bbq", "grilled vegetables", "watermelon", "ice cream", "lemonade"],
    # "Winter": ["stew", "hot chocolate", "roast", "gingerbread", "soup"],
    # "Fall/Autumn": ["pumpkin", "apple pie", "squash", "roasted vegetables", "cider"],
    # "Back to School": ["lunchbox", "snacks", "granola bars", "mac and cheese", "sandwich"],
    # "Graduation": ["sheet cake", "finger foods", "punch", "party food"],
    # "Winter Holidays (generic)": ["cookies", "hot cocoa", "spiced cider", "mulled wine", "roast dinner"],
    # "New Year's Eve": ["champagne", "shrimp cocktail", "finger food", "party snacks"],
    # "Groundhog Day": [
    #     "groundhog", "groundhog day", "february 2"
    # ],
    # "April Fools' Day": [
    #     "april fools", "prank", "trick recipe", "joke dish"
    # ],
    # "Washington’s Birthday": [
    #     "washington’s birthday", "president’s day", "cherry pie", "patriotic"
    # ],
    # "Boxing Day": [
    #     "boxing day", "leftover", "british holiday", "post-christmas"
    # ],
    # "Bastille Day": [
    #     "bastille day", "french national day", "quatorze juillet", "french revolution"
    # ],
    # "All Saints' Day": [
    #     "all saints", "saints day", "november 1", "religious holiday"
    # ],
    # "Chinese Mid-Autumn Festival": [
    #     "mid-autumn", "mooncake", "harvest moon", "chinese festival"
    # ],
    # "Día de los Muertos": [
    #     "dia de los muertos", "day of the dead", "pan de muerto", "calaveras"
    # ],
    # "Guru Nanak Jayanti": [
    #     "guru nanak", "gurpurab", "karah prasad", "sikh festival"
    # ],
    # "Vesak": [
    #     "vesak", "buddha day", "buddha’s birthday", "buddhist holiday"
    # ],
    # "Pongal": [
    #     "pongal", "sweet pongal", "ven pongal", "harvest festival", "tamil celebration"
    # ],
    # "Thaipusam": [
    #     "thaipusam", "kavadi", "hindu festival", "murugan"
    # ],
    # "Songkran": [
    #     "songkran", "thai new year", "water festival", "thai traditional food"
    # ],
    # "Ash Wednesday": [
    #     "ash wednesday", "fasting", "lent", "no meat"
    # ],
    # "Good Friday": [
    #     "good friday", "fish", "fasting", "easter weekend"
    # ],
    # "Chuseok": [
    #     "chuseok", "korean thanksgiving", "songpyeon", "hangwa"
    # ],
    # "Loy Krathong": [
    #     "loy krathong", "thai festival", "floating lanterns", "coconut desserts"
    # ],
    # "Feast of the Assumption": [
    #     "feast of the assumption", "assumption day", "catholic feast", "august 15"
    # ],
    # "National Day of Prayer": [
    #     "national day of prayer", "prayer breakfast", "interfaith", "religious unity"
    # ]



cuisine_keywords = {
    "American": [
        "mac and cheese", "apple pie", "fried chicken", "cornbread", "burger", "meatloaf", "buffalo wings", "barbecue", "sloppy joe"
    ],
    "Mexican": [
        "taco", "enchilada", "quesadilla", "salsa", "guacamole", "chili con carne", "tamale", "burrito", "mole", "churro"
    ],
    "Italian": [
        "pasta", "spaghetti", "lasagna", "marinara", "parmesan", "mozzarella", "risotto", "carbonara", "gnocchi", "bruschetta", "tiramisu"
    ],
    "Chinese": [
        "fried rice", "soy sauce", "dumpling", "spring roll", "chow mein", "kung pao", "szechuan", "hoisin", "bok choy", "lo mein"
    ],
    "Indian": [
        "masala", "dal", "curry", "biryani", "tandoori", "paneer", "roti", "naan", "samosa", "garam masala", "chutney", "halwa"
    ],
    "Thai": [
        "thai basil", "pad thai", "green curry", "red curry", "lemongrass", "coconut milk", "fish sauce", "peanut sauce", "tom yum"
    ],
    "Japanese": [
        "sushi", "teriyaki", "miso", "ramen", "tempura", "udon", "sashimi", "soy sauce", "mirin", "dashi"
    ],
    "French": [
        "coq au vin", "ratatouille", "croissant", "baguette", "crème brûlée", "quiche", "soufflé", "béchamel", "duck confit"
    ],
    "Korean": [
        "kimchi", "bulgogi", "bibimbap", "gochujang", "jjigae", "korean bbq", "rice cakes", "banchan"
    ],
    "Vietnamese": [
        "pho", "banh mi", "spring roll", "fish sauce", "lemongrass", "rice noodles", "nuoc cham"
    ],
    "Middle Eastern": [
        "hummus", "falafel", "shawarma", "tabbouleh", "tahini", "kebab", "za'atar", "pita", "baklava"
    ],
    "Mediterranean": [
        "olive oil", "feta", "tzatziki", "gyro", "grilled vegetables", "hummus", "kalamata", "couscous", "dolma"
    ],
    "Greek": [
        "gyro", "tzatziki", "feta", "moussaka", "spanakopita", "souvlaki", "olives", "baklava"
    ],
    "Spanish": [
        "paella", "tapas", "churros", "gazpacho", "tortilla española", "jamón", "patatas bravas"
    ],
    "Caribbean": [
        "jerk", "plantain", "rice and peas", "curry goat", "ackee", "saltfish", "rum cake"
    ],
    "German": [
        "sauerkraut", "bratwurst", "pretzel", "schnitzel", "spätzle", "apple strudel"
    ],
    "Brazilian": [
        "feijoada", "pão de queijo", "churrasco", "moqueca", "brigadeiro", "farofa"
    ],
    "Turkish": [
        "kebab", "borek", "dolma", "baklava", "lahmacun", "pide", "menemen"
    ],
    "Russian": [
        "borscht", "pelmeni", "beef stroganoff", "blini", "shashlik", "pirozhki"
    ],
    "Ethiopian": [
        "injera", "doro wat", "berbere", "kitfo", "shiro"
    ],
    "Moroccan": [
        "tagine", "couscous", "harira", "ras el hanout", "preserved lemon", "moroccan", "kefta", "bastilla"
    ],
    "British": [
        "fish and chips", "shepherd's pie", "bangers and mash", "scone", "yorkshire pudding", "english breakfast", "british", "mince pie"
    ],
    "Polish": [
        "pierogi", "golabki", "bigos", "kielbasa", "polish", "placki", "barszcz"
    ],
    "Jewish": [
        "matzo", "latkes", "brisket", "kugel", "bagel", "challah", "lox", "gefilte fish", "kosher", "jewish"
    ],
    "Filipino": [
        "adobo", "sinangag", "pancit", "lechon", "lumpia", "kare kare", "halo-halo", "filipino", "longganisa"
    ],
    "Peruvian": [
        "ceviche", "aji de gallina", "lomo saltado", "papa a la huancaína", "anticuchos", "peruvian", "rocoto", "causa"
    ],
    "Argentinian": [
        "chimichurri", "empanada", "asado", "milanesa", "dulce de leche", "mate", "argentinian", "choripán"
    ],
    "Pakistani": [
        "biryani", "nihari", "haleem", "pakora", "chapli kebab", "roti", "pakistani", "qorma", "kheer"
    ],
    "Cajun": [
        "jambalaya", "gumbo", "etouffee", "cajun spice", "andouille", "dirty rice", "cajun"
    ],
    "Creole": [
        "creole", "shrimp creole", "red beans and rice", "okra", "crawfish étouffée", "new orleans"
    ],
    "Tex-Mex": [
        "fajita", "queso", "tex-mex", "chili con carne", "nachos", "burrito", "enchilada", "salsa", "refried beans"
    ],
    "Californian": [
        "california roll", "avocado toast", "fusion", "fresh produce", "californian", "sourdough", "grain bowl", "farm-to-table"
    ],
    "New England": [
        "clam chowder", "lobster roll", "cranberry", "maple syrup", "baked beans", "boston", "new england"
    ],
    "Hawaiian": [
        "poke", "kalua pig", "loco moco", "haupia", "spam musubi", "pineapple", "hawaiian", "poi"
    ],
    "Amish": [
        "shoofly pie", "whoopie pie", "chicken pot pie", "noodles", "apple butter", "amish", "dumplings", "egg noodles"
    ],
    "Soul Food": [
        "collard greens", "fried chicken", "mac and cheese", "sweet potato pie", "cornbread", "black-eyed peas", "soul food", "grits"
    ],
    "Barbecue": [
        "barbecue", "brisket", "ribs", "pulled pork", "bbq sauce", "smoked", "grilled", "pit bbq"
    ],
    "Appalachian": [
        "soup beans", "cornbread", "apple stack cake", "ramp", "poke sallet", "molasses", "appalachian", "chow chow"
    ],
    "Southern": ["fried chicken", "collard greens", "grits", "biscuits", "bbq", "gumbo", "jambalaya", "pecan pie", "southern", "georgia", "florida", "nashville", "louisiana", "texas"],
    "Midwestern": ["hotdish", "deep dish", "bratwurst", "cheese curds", "casserole", "buttered corn", "illinois", "minnesota", "iowa", "ohio", "wisconsin"],
    "Pacific Northwest": ["salmon", "wild berries", "rainier cherry", "hazelnut", "espresso", "pacific northwest", "seattle", "oregon", "idaho"],
    "Northeast": ["lobster roll", "clam chowder", "maple syrup", "bagel", "cheesesteak", "cranberry", "boston", "vermont", "new england"],
    "West": ["sourdough", "avocado", "poke", "kale salad", "cioppino", "grilled fish", "california", "colorado", "oregon", "washington"],
    "Southwest": ["chili", "enchilada", "fajita", "tex-mex", "tamale", "salsa", "taco", "hatch chile", "new mexico", "arizona", "southwestern"],
    "North": ["northern", "cold weather dishes", "stew", "hearty soup", "midwest", "northeast", "snow", "comfort food"]
}
    # "Lebanese": [
    #     "hummus", "tabbouleh", "kibbeh", "baba ghanoush", "fattoush", "manakish"
    # ]
    # "African": [
    #     "injera", "jollof", "egusi", "piri piri", "suya", "fufu", "tagine", "bobotie", "berbere"
    # ],




diet_keywords = {
    "Vegetarian": [
        "vegetarian", "paneer", "cheese", "dal", "eggplant", "zucchini", "vegetable curry", "chickpeas", "tofu"
    ],
    "Vegan": [
        "vegan", "tofu", "plant-based", "cashew cheese", "nutritional yeast", "almond milk", "coconut milk", "no honey", "dairy-free"
    ],
    "Gluten-Free": [
        "gluten-free", "rice flour", "almond flour", "cornmeal", "quinoa", "millet", "buckwheat", "arrowroot"
    ],
    "Keto": [
        "keto", "low carb", "avocado", "zucchini noodles", "almond flour", "cauliflower rice", "cheese crisps", "butter coffee"
    ],
    "Paleo": [
        "paleo", "grass-fed", "ghee", "sweet potatoes", "coconut flour", "bone broth", "no legumes", "no dairy", "natural"
    ],
    "Low-Carb": [
        "low carb", "zoodles", "egg muffins", "cauliflower mash", "cheddar crisps", "keto-friendly"
    ],
    "High-Protein": [
        "high protein", "chicken breast", "lentils", "egg whites", "whey", "quinoa", "cottage cheese", "tuna"
    ],
    "Pescatarian": [
        "pescatarian", "salmon", "shrimp", "tuna", "mackerel", "cod", "seafood", "fish curry"
    ],
    "Dairy-Free": [
        "dairy-free", "almond milk", "coconut milk", "oat milk", "vegan butter", "no cheese", "no cream"
    ],
    "Nut-Free": [
        "nut-free", "no nuts", "sunflower seed butter", "pumpkin seeds", "allergy-safe"
    ],
    "Soy-Free": [
        "soy-free", "no soy", "coconut aminos", "pea protein", "soy allergy"
    ],
    "Sugar-Free": [
        "sugar-free", "no added sugar", "stevia", "monk fruit", "xylitol", "no refined sugar"
    ],
    "Halal": [
        "halal", "zabiha", "shami kabab", "halal-certified", "no pork", "halal chicken"
    ],
    "Kosher": [
        "kosher", "kosher salt", "gefilte fish", "matzo", "no pork", "kosher meat", "pareve"
    ],
    "Low-Sodium": [
        "low sodium", "reduced salt", "no salt added", "salt-free", "heart-healthy"
    ],
    "Diabetic-Friendly": [
        "diabetic-friendly", "low glycemic", "no added sugar", "whole grains", "fiber-rich", "sugar-free", "glycemic control"
    ],
    "Raw Food": [
        "raw food", "raw vegan", "uncooked", "soaked nuts", "dehydrated", "living food", "sprouted"
    ]
}
    # "Whole30": [
    #     "whole30", "whole foods only", "no grains", "no sugar", "no legumes", "compliant", "ghee"
    # ],
    # "Flexitarian": [
    #     "flexitarian", "mostly vegetarian", "plant-rich", "meat occasionally", "semi-vegetarian"
    # ],
    # "Clean Eating": [
    #     "clean eating", "whole food", "minimally processed", "natural", "unprocessed", "organic"
    # ],




# region_keywords = {

# }

# %%
tags_to_insert = {
    "holiday": list(holiday_keywords.keys()),
    "diet": list(diet_keywords.keys()),
    "cuisine": list(cuisine_keywords.keys())


    # "region": list(region_keywords.keys())
}

# %%
# insert tags into the database
with engine.connect() as conn:
    for tag_type, tag_names in tags_to_insert.items():
        for name in tag_names:

            result = conn.execute(text("SELECT 1 FROM tags WHERE tag_name = :name AND tag_type = :type"),
                                  {"name": name, "type": tag_type})
            if not result.first():
                conn.execute(text("INSERT INTO tags (tag_name, tag_type) VALUES (:name, :type)"),
                             {"name": name, "type": tag_type})
    conn.commit()

# %%
# insert keywords into tag_keywords table
with engine.begin() as conn:
    # holidays
    for tag_name, keywords in holiday_keywords.items():
        
        result = conn.execute(text("""
            SELECT tag_id FROM tags WHERE tag_name = :name AND tag_type = 'holiday'
        """), {"name": tag_name}).fetchone()
        
        if not result:
                print(f"Tag '{tag_name}' not found in tags table.")
                continue

        tag_id = result[0]

        for keyword in keywords:
            
            exists = conn.execute(text("""
                SELECT 1 FROM tag_keywords WHERE tag_id = :tag_id AND keyword = :keyword
            """), {"tag_id": tag_id, "keyword": keyword}).fetchone()

            if not exists:
                conn.execute(text("""
                    INSERT INTO tag_keywords (tag_id, keyword) VALUES (:tag_id, :keyword)
                """), {"tag_id": tag_id, "keyword": keyword})

    # cuisines
    for tag_name, keywords in cuisine_keywords.items():

        result = conn.execute(text("""
            SELECT tag_id FROM tags WHERE tag_name = :name AND tag_type = 'cuisine'
        """), {"name": tag_name}).fetchone()

        if not result:
            print(f"Tag '{tag_name}' not found in tags table.")
            continue

        tag_id = result[0]

        for keyword in keywords:

            exists = conn.execute(text("""
                SELECT 1 FROM tag_keywords WHERE tag_id = :tag_id AND keyword = :keyword
            """), {"tag_id": tag_id, "keyword": keyword}).fetchone()

            if not exists:
                conn.execute(text("""
                    INSERT INTO tag_keywords (tag_id, keyword) VALUES (:tag_id, :keyword)
                """), {"tag_id": tag_id, "keyword": keyword})

    # diets
    for tag_name, keywords in diet_keywords.items():

        result = conn.execute(text("""
            SELECT tag_id FROM tags WHERE tag_name = :name AND tag_type = 'diet'
        """), {"name": tag_name}).fetchone()

        if not result:
            print(f"Tag '{tag_name}' not found in tags table.")
            continue

        tag_id = result[0]

        for keyword in keywords:

            exists = conn.execute(text("""
                SELECT 1 FROM tag_keywords WHERE tag_id = :tag_id AND keyword = :keyword
            """), {"tag_id": tag_id, "keyword": keyword}).fetchone()

            if not exists:
                conn.execute(text("""
                    INSERT INTO tag_keywords (tag_id, keyword) VALUES (:tag_id, :keyword)
                """), {"tag_id": tag_id, "keyword": keyword})

    # regions
    # for tag_name, keywords in region_keywords.items():

    #     result = conn.execute(text("""
    #         SELECT tag_id FROM tags WHERE tag_name = :name AND tag_type = 'region'
    #     """), {"name": tag_name}).fetchone()

    #     if not result:
    #         print(f"Tag '{tag_name}' not found in tags table.")
    #         continue

    #     tag_id = result[0]

    #     for keyword in keywords:

    #         exists = conn.execute(text("""
    #             SELECT 1 FROM tag_keywords WHERE tag_id = :tag_id AND keyword = :keyword
    #         """), {"tag_id": tag_id, "keyword": keyword}).fetchone()

    #         if not exists:
    #             conn.execute(text("""
    #                 INSERT INTO tag_keywords (tag_id, keyword) VALUES (:tag_id, :keyword)
    #             """), {"tag_id": tag_id, "keyword": keyword})
        
print("Keywords inserted into tag_keywords.")
# Out:
# ✅ Keywords inserted into tag_keywords.

# %%
def fetch_all_tag_keywords(conn):
    result = conn.execute(text("SELECT tag_id, keyword FROM tag_keywords")).mappings()
    
    tag_map = {}
    for row in result:
        tag_id = row['tag_id']
        keyword = row['keyword'].lower()
        if tag_id not in tag_map:
            tag_map[tag_id] = set()
        tag_map[tag_id].add(keyword)

    return tag_map


def fetch_all_recipes(conn):
    result = conn.execute(text("SELECT recipe_id, recipe_name, instructions FROM recipe")).mappings()
    return result.fetchall()


def tag_recipe(conn, recipe_id, tag_id):
    exists = conn.execute(text("""
        SELECT 1 FROM recipe_tags_mapping WHERE recipe_id = :rid AND tag_id = :tid
    """), {"rid": recipe_id, "tid": tag_id}).first()
    
    if not exists:
        conn.execute(text("""
            INSERT INTO recipe_tags_mapping (recipe_id, tag_id) VALUES (:rid, :tid)
        """), {"rid": recipe_id, "tid": tag_id})

def auto_tag_recipes():
    with engine.begin() as conn:
        tag_map = fetch_all_tag_keywords(conn)
        recipes = fetch_all_recipes(conn)

        for recipe in recipes:
            content = f"{recipe['recipe_name']} {recipe['instructions']}".lower()
            for tag_id, keywords in tag_map.items():
                if any(kw in content for kw in keywords):
                    tag_recipe(conn, recipe['recipe_id'], tag_id)
    print("Recipes auto-tagged based on keywords.")

def tag_recipe_by_id(recipe_id):
    with engine.begin() as conn:
        tag_map = fetch_all_tag_keywords(conn)
        recipe = conn.execute(text("SELECT recipe_name, instructions FROM recipe WHERE recipe_id = :rid"),
                              {"rid": recipe_id}).fetchone()
        
        if not recipe:
            print(f"Recipe with ID {recipe_id} not found.")
            return
        
        content = f"{recipe['recipe_name']} {recipe['instructions']}".lower()
        
        for tag_id, keywords in tag_map.items():
            if any(kw in content for kw in keywords):
                tag_recipe(conn, recipe_id, tag_id)
    print(f"Recipe {recipe_id} auto-tagged based on keywords.")
# Out:
# Tagging completed.

# %%
if __name__ == "__main__":
    
    # tag all recipes based on keywords
    auto_tag_recipes()

    # provide a specific recipe ID to tag
    # tag_recipe_by_id(1)
